# %% [markdown]
# # Cluster 2

# %%
import pandas as pd

# %%
df = pd.read_csv('../../Clusters/cluster_2.csv')

# %%
df.head()
# Out:
#    Index  Bankrupt?  ROA(C) before interest and depreciation before interest  \
# 0      3          0                                           0.483401
# 1      6          0                                           0.465071
# 2     11          0                                           0.442500
# 3     15          0                                           0.445230
# 4     37          0                                           0.491201
#
#    ROA(A) before interest and % after tax  \
# 0                                0.556694
# 1                                0.533689
# 2                                0.507196
# 3                                0.500273
# 4                                0.556095
#
#    ROA(B) before interest and depreciation after tax  Operating Gross Margin  \
# 0                                           0.536164                0.602445
# 1                                           0.516944                0.594740
# 2                                           0.494941                0.598906
# 3                                           0.500990                0.601277
# 4                                           0.544944                0.599728
#
#    Realized Sales Gross Margin  Operating Profit Rate  \
# 0                     0.602445               0.999035
# 1                     0.594740               0.998962
# 2                     0.598812               0.998927
# 3                     0.601277               0.998940
# 4                     0.599728               0.999011
#
#    Pre-tax net Interest Rate  After-tax net Interest Rate  ...  \
# 0                   0.797458                     0.809380  ...
# 1                   0.797393                     0.809313  ...
# 2                   0.797298                     0.809236  ...
# 3                   0.797289                     0.809233  ...
# 4                   0.797414                     0.809335  ...
#
#    Total assets to GNP price  No-credit Interval  Gross Profit to Sales  \
# 0                   0.002177            0.621610               0.602444
# 1                   0.054013            0.613323               0.594736
# 2                   0.009173            0.624087               0.598903
# 3                   0.002127            0.623572               0.601277
# 4                   0.003267            0.622668               0.599728
#
#    Net Income to Stockholder's Equity  Liability to Equity  \
# 0                            0.841891             0.293391
# 1                            0.840085             0.285529
# 2                            0.838903             0.278959
# 3                            0.837951             0.282391
# 4                            0.840690             0.282521
#
#    Degree of Financial Leverage (DFL)  \
# 0                            0.027063
# 1                            0.029521
# 2                            0.026643
# 3                            0.026686
# 4                            0.028464
#
#    Interest Coverage Ratio (Interest expense to EBIT)  Net Income Flag  \
# 0                                           0.566190                 1
# 1                                           0.568791                 1
# 2                                           0.564335                 1
# 3                                           0.564603                 1
# 4                                           0.568246                 1
#
#    Equity to Liability  Cluster
# 0             0.015406        2
# 1             0.019155        2
# 2             0.032862        2
# 3             0.022788        2
# 4             0.022580        2
#
# [5 rows x 98 columns]

# %%
print(df.shape)
df.describe()
# Out:
# (904, 98)
#              Index   Bankrupt?  \
# count   904.000000  904.000000
# mean   2842.140487    0.111726
# std    1663.201376    0.315203
# min       3.000000    0.000000
# 25%    1358.750000    0.000000
# 50%    2835.000000    0.000000
# 75%    4275.000000    0.000000
# max    5802.000000    1.000000
#
#        ROA(C) before interest and depreciation before interest  \
# count                                         904.000000
# mean                                            0.454117
# std                                             0.058792
# min                                             0.000000
# 25%                                             0.435187
# 50%                                             0.469410
# 75%                                             0.489945
# max                                             0.574367
#
#        ROA(A) before interest and % after tax  \
# count                              904.000000
# mean                                 0.506552
# std                                  0.070122
# min                                  0.006923
# 25%                                  0.484409
# 50%                                  0.527775
# 75%                                  0.548585
# max                                  0.635794
#
#        ROA(B) before interest and depreciation after tax  \
# count                                         904.000000
# mean                                            0.502734
# std                                             0.064373
# min                                             0.000000
# 25%                                             0.481784
# 50%                                             0.520370
# 75%                                             0.541290
# max                                             0.630708
#
#        Operating Gross Margin  Realized Sales Gross Margin  \
# count              904.000000                   904.000000
# mean                 0.603107                     0.603115
# std                  0.010743                     0.010746
# min                  0.448342                     0.448342
# 25%                  0.598178                     0.598176
# 50%                  0.602445                     0.602427
# 75%                  0.607073                     0.607124
# max                  0.657778                     0.657778
#
#        Operating Profit Rate  Pre-tax net Interest Rate  \
# count             904.000000                 904.000000
# mean                0.998906                   0.797240
# std                 0.000856                   0.001030
# min                 0.973875                   0.767759
# 25%                 0.998903                   0.797234
# 50%                 0.998967                   0.797357
# 75%                 0.999011                   0.797420
# max                 0.999309                   0.797801
#
#        After-tax net Interest Rate  ...  Total assets to GNP price  \
# count                   904.000000  ...               9.040000e+02
# mean                      0.809175  ...               4.846239e+07
# std                       0.000968  ...               5.924934e+08
# min                       0.781429  ...               1.015560e-04
# 25%                       0.809171  ...               8.545638e-04
# 50%                       0.809285  ...               1.724900e-03
# 75%                       0.809341  ...               4.034450e-03
# max                       0.809703  ...               9.820000e+09
#
#        No-credit Interval  Gross Profit to Sales  \
# count          904.000000             904.000000
# mean             0.623500               0.603105
# std              0.003325               0.010743
# min              0.591033               0.448342
# 25%              0.623363               0.598179
# 50%              0.623665               0.602444
# 75%              0.623804               0.607070
# max              0.690700               0.657775
#
#        Net Income to Stockholder's Equity  Liability to Equity  \
# count                          904.000000           904.000000
# mean                             0.834917             0.286594
# std                              0.037129             0.032529
# min                              0.000000             0.276702
# 25%                              0.836821             0.280625
# 50%                              0.839606             0.282761
# 75%                              0.840741             0.285957
# max                              0.846063             1.000000
#
#        Degree of Financial Leverage (DFL)  \
# count                          904.000000
# mean                             0.029445
# std                              0.026484
# min                              0.021582
# 25%                              0.026646
# 50%                              0.026779
# 75%                              0.027225
# max                              0.540672
#
#        Interest Coverage Ratio (Interest expense to EBIT)  Net Income Flag  \
# count                                         904.000000             904.0
# mean                                            0.565089               1.0
# std                                             0.013683               0.0
# min                                             0.319590               1.0
# 25%                                             0.564535               1.0
# 50%                                             0.565158               1.0
# 75%                                             0.566860               1.0
# max                                             0.664336               1.0
#
#        Equity to Liability  Cluster
# count           904.000000    904.0
# mean              0.023270      2.0
# std               0.006746      0.0
# min               0.010365      2.0
# 25%               0.018816      2.0
# 50%               0.022212      2.0
# 75%               0.026518      2.0
# max               0.058145      2.0
#
# [8 rows x 98 columns]

# %% [markdown]
# Notice than some features are normalized between 0 and 1. Some features such as "Total assets to GNP price" are not normalized with some samples having larges values. All features seem to be numerical

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 98 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Index                                                    904 non-null    int64
#  1   Bankrupt?                                                904 non-null    int64
#  2   ROA(C) before interest and depreciation before interest  904 non-null    float64
#  3   ROA(A) before interest and % after tax                   904 non-null    float64
#  4   ROA(B) before interest and depreciation after tax        904 non-null    float64
#  5   Operating Gross Margin                                   904 non-null    float64
#  6   Realized Sales Gross Margin                              904 non-null    float64
#  7   Operating Profit Rate                                    904 non-null    float64
#  8   Pre-tax net Interest Rate                                904 non-null    float64
#  9   After-tax net Interest Rate                              904 non-null    float64
#  10  Non-industry income and expenditure/revenue              904 non-null    float64
#  11  Continuous interest rate (after tax)                     904 non-null    float64
#  12  Operating Expense Rate                                   904 non-null    float64
#  13  Research and development expense rate                    904 non-null    float64
#  14  Cash flow rate                                           904 non-null    float64
#  15  Interest-bearing debt interest rate                      904 non-null    float64
#  16  Tax rate (A)                                             904 non-null    float64
#  17  Net Value Per Share (B)                                  904 non-null    float64
#  18  Net Value Per Share (A)                                  904 non-null    float64
#  19  Net Value Per Share (C)                                  904 non-null    float64
#  20  Persistent EPS in the Last Four Seasons                  904 non-null    float64
#  21  Cash Flow Per Share                                      904 non-null    float64
#  22  Revenue Per Share (Yuan ¥)                               904 non-null    float64
#  23  Operating Profit Per Share (Yuan ¥)                      904 non-null    float64
#  24  Per Share Net profit before tax (Yuan ¥)                 904 non-null    float64
#  25  Realized Sales Gross Profit Growth Rate                  904 non-null    float64
#  26  Operating Profit Growth Rate                             904 non-null    float64
#  27  After-tax Net Profit Growth Rate                         904 non-null    float64
#  28  Regular Net Profit Growth Rate                           904 non-null    float64
#  29  Continuous Net Profit Growth Rate                        904 non-null    float64
#  30  Total Asset Growth Rate                                  904 non-null    float64
#  31  Net Value Growth Rate                                    904 non-null    float64
#  32  Total Asset Return Growth Rate Ratio                     904 non-null    float64
#  33  Cash Reinvestment %                                      904 non-null    float64
#  34  Current Ratio                                            904 non-null    float64
#  35  Quick Ratio                                              904 non-null    float64
#  36  Interest Expense Ratio                                   904 non-null    float64
#  37  Total debt/Total net worth                               904 non-null    float64
#  38  Debt ratio %                                             904 non-null    float64
#  39  Net worth/Assets                                         904 non-null    float64
#  40  Long-term fund suitability ratio (A)                     904 non-null    float64
#  41  Borrowing dependency                                     904 non-null    float64
#  42  Contingent liabilities/Net worth                         904 non-null    float64
#  43  Operating profit/Paid-in capital                         904 non-null    float64
#  44  Net profit before tax/Paid-in capital                    904 non-null    float64
#  45  Inventory and accounts receivable/Net value              904 non-null    float64
#  46  Total Asset Turnover                                     904 non-null    float64
#  47  Accounts Receivable Turnover                             904 non-null    float64
#  48  Average Collection Days                                  904 non-null    float64
#  49  Inventory Turnover Rate (times)                          904 non-null    float64
#  50  Fixed Assets Turnover Frequency                          904 non-null    float64
#  51  Net Worth Turnover Rate (times)                          904 non-null    float64
#  52  Revenue per person                                       904 non-null    float64
#  53  Operating profit per person                              904 non-null    float64
#  54  Allocation rate per person                               904 non-null    float64
#  55  Working Capital to Total Assets                          904 non-null    float64
#  56  Quick Assets/Total Assets                                904 non-null    float64
#  57  Current Assets/Total Assets                              904 non-null    float64
#  58  Cash/Total Assets                                        904 non-null    float64
#  59  Quick Assets/Current Liability                           904 non-null    float64
#  60  Cash/Current Liability                                   904 non-null    float64
#  61  Current Liability to Assets                              904 non-null    float64
#  62  Operating Funds to Liability                             904 non-null    float64
#  63  Inventory/Working Capital                                904 non-null    float64
#  64  Inventory/Current Liability                              904 non-null    float64
#  65  Current Liabilities/Liability                            904 non-null    float64
#  66  Working Capital/Equity                                   904 non-null    float64
#  67  Current Liabilities/Equity                               904 non-null    float64
#  68  Long-term Liability to Current Assets                    904 non-null    float64
#  69  Retained Earnings to Total Assets                        904 non-null    float64
#  70  Total income/Total expense                               904 non-null    float64
#  71  Total expense/Assets                                     904 non-null    float64
#  72  Current Asset Turnover Rate                              904 non-null    float64
#  73  Quick Asset Turnover Rate                                904 non-null    float64
#  74  Working capitcal Turnover Rate                           904 non-null    float64
#  75  Cash Turnover Rate                                       904 non-null    float64
#  76  Cash Flow to Sales                                       904 non-null    float64
#  77  Fixed Assets to Assets                                   904 non-null    float64
#  78  Current Liability to Liability                           904 non-null    float64
#  79  Current Liability to Equity                              904 non-null    float64
#  80  Equity to Long-term Liability                            904 non-null    float64
#  81  Cash Flow to Total Assets                                904 non-null    float64
#  82  Cash Flow to Liability                                   904 non-null    float64
#  83  CFO to Assets                                            904 non-null    float64
#  84  Cash Flow to Equity                                      904 non-null    float64
#  85  Current Liability to Current Assets                      904 non-null    float64
#  86  Liability-Assets Flag                                    904 non-null    int64
#  87  Net Income to Total Assets                               904 non-null    float64
#  88  Total assets to GNP price                                904 non-null    float64
#  89  No-credit Interval                                       904 non-null    float64
#  90  Gross Profit to Sales                                    904 non-null    float64
#  91  Net Income to Stockholder's Equity                       904 non-null    float64
#  92  Liability to Equity                                      904 non-null    float64
#  93  Degree of Financial Leverage (DFL)                       904 non-null    float64
#  94  Interest Coverage Ratio (Interest expense to EBIT)       904 non-null    float64
#  95  Net Income Flag                                          904 non-null    int64
#  96  Equity to Liability                                      904 non-null    float64
#  97  Cluster                                                  904 non-null    int64
# dtypes: float64(93), int64(5)
# memory usage: 692.3 KB

# %%
# Find number and percentage of companies with Bankrupt? = 1
bankrupt_count = (df["Bankrupt?"] == 1).sum()
total_count = len(df)
bankrupt_percentage = (bankrupt_count / total_count) * 100

print("Bankruptcy Distribution:")
print("="*60)
print(f"Companies with Bankrupt? = 1: {bankrupt_count}")
print(f"Companies with Bankrupt? = 0: {total_count - bankrupt_count}")
print(f"Total companies: {total_count}")
print(f"\nBankruptcy Rate: {bankrupt_percentage:.2f}%")
print(f"Non-bankruptcy Rate: {100 - bankrupt_percentage:.2f}%")
# Out:
# Bankruptcy Distribution:
# ============================================================
# Companies with Bankrupt? = 1: 101
# Companies with Bankrupt? = 0: 803
# Total companies: 904
#
# Bankruptcy Rate: 11.17%
# Non-bankruptcy Rate: 88.83%

# %%
# See exact names of all features
df.columns.tolist()
# Out:
# ['Index',
#  'Bankrupt?',
#  'ROA(C) before interest and depreciation before interest',
#  'ROA(A) before interest and % after tax',
#  'ROA(B) before interest and depreciation after tax',
#  'Operating Gross Margin',
#  'Realized Sales Gross Margin',
#  'Operating Profit Rate',
#  'Pre-tax net Interest Rate',
#  'After-tax net Interest Rate',
#  'Non-industry income and expenditure/revenue',
#  'Continuous interest rate (after tax)',
#  'Operating Expense Rate',
#  'Research and development expense rate',
#  'Cash flow rate',
#  'Interest-bearing debt interest rate',
#  'Tax rate (A)',
#  'Net Value Per Share (B)',
#  'Net Value Per Share (A)',
#  'Net Value Per Share (C)',
#  'Persistent EPS in the Last Four Seasons',
#  'Cash Flow Per Share',
#  'Revenue Per Share (Yuan ¥)',
#  'Operating Profit Per Share (Yuan ¥)',
#  'Per Share Net profit before tax (Yuan ¥)',
#  'Realized Sales Gross Profit Growth Rate',
#  'Operating Profit Growth Rate',
#  'After-tax Net Profit Growth Rate',
#  'Regular Net Profit Growth Rate',
#  'Continuous Net Profit Growth Rate',
#  'Total Asset Growth Rate',
#  'Net Value Growth Rate',
#  'Total Asset Return Growth Rate Ratio',
#  'Cash Reinvestment %',
#  'Current Ratio',
#  'Quick Ratio',
#  'Interest Expense Ratio',
#  'Total debt/Total net worth',
#  'Debt ratio %',
#  'Net worth/Assets',
#  'Long-term fund suitability ratio (A)',
#  'Borrowing dependency',
#  'Contingent liabilities/Net worth',
#  'Operating profit/Paid-in capital',
#  'Net profit before tax/Paid-in capital',
#  'Inventory and accounts receivable/Net value',
#  'Total Asset Turnover',
#  'Accounts Receivable Turnover',
#  'Average Collection Days',
#  'Inventory Turnover Rate (times)',
#  'Fixed Assets Turnover Frequency',
#  'Net Worth Turnover Rate (times)',
#  'Revenue per person',
#  'Operating profit per person',
#  'Allocation rate per person',
#  'Working Capital to Total Assets',
#  'Quick Assets/Total Assets',
#  'Current Assets/Total Assets',
#  'Cash/Total Assets',
#  'Quick Assets/Current Liability',
#  'Cash/Current Liability',
#  'Current Liability to Assets',
#  'Operating Funds to Liability',
#  'Inventory/Working Capital',
#  'Inventory/Current Liability',
#  'Current Liabilities/Liability',
#  'Working Capital/Equity',
#  'Current Liabilities/Equity',
#  'Long-term Liability to Current Assets',
#  'Retained Earnings to Total Assets',
#  'Total income/Total expense',
#  'Total expense/Assets',
#  'Current Asset Turnover Rate',
#  'Quick Asset Turnover Rate',
#  'Working capitcal Turnover Rate',
#  'Cash Turnover Rate',
#  'Cash Flow to Sales',
#  'Fixed Assets to Assets',
#  'Current Liability to Liability',
#  'Current Liability to Equity',
#  'Equity to Long-term Liability',
#  'Cash Flow to Total Assets',
#  'Cash Flow to Liability',
#  'CFO to Assets',
#  'Cash Flow to Equity',
#  'Current Liability to Current Assets',
#  'Liability-Assets Flag',
#  'Net Income to Total Assets',
#  'Total assets to GNP price',
#  'No-credit Interval',
#  'Gross Profit to Sales',
#  "Net Income to Stockholder's Equity",
#  'Liability to Equity',
#  'Degree of Financial Leverage (DFL)',
#  'Interest Coverage Ratio (Interest expense to EBIT)',
#  'Net Income Flag',
#  'Equity to Liability',
#  'Cluster']

# %% [markdown]
# ## Boolean features

# %%
df["Net Income Flag"].describe()
# Out:
# count    904.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: Net Income Flag, dtype: float64

# %%
# Check unique values for Net Income Flag
print("Unique values in Net Income Flag:")
print(df["Net Income Flag"].unique())
print(f"\nValue counts for Net Income Flag:")
print(df["Net Income Flag"].value_counts())
print(f"\nTotal samples: {len(df)}")
print(f"Samples with Net Income Flag = 1: {(df['Net Income Flag'] == 1).sum()}")
print(f"All values are 1: {(df['Net Income Flag'] == 1).all()}")
# Out:
# Unique values in Net Income Flag:
# [1]
#
# Value counts for Net Income Flag:
# Net Income Flag
# 1    904
# Name: count, dtype: int64
#
# Total samples: 904
# Samples with Net Income Flag = 1: 904
# All values are 1: True

# %%
df["Liability-Assets Flag"].describe()
# Out:
# count    904.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: Liability-Assets Flag, dtype: float64

# %%
# Check unique values for Net Income Flag
print("Unique values in Liability-Assets Flag:")
print(df["Liability-Assets Flag"].unique())
print(f"\nValue counts for Liability-Assets Flag:")
print(df["Liability-Assets Flag"].value_counts())
print(f"\nTotal samples: {len(df)}")
print(f"Samples with Liability-Assets Flag = 1: {(df['Liability-Assets Flag'] == 1).sum()}")
print(f"All values are 0: {(df['Liability-Assets Flag'] == 0).all()}")
# Out:
# Unique values in Liability-Assets Flag:
# [0]
#
# Value counts for Liability-Assets Flag:
# Liability-Assets Flag
# 0    904
# Name: count, dtype: int64
#
# Total samples: 904
# Samples with Liability-Assets Flag = 1: 0
# All values are 0: True

# %% [markdown]
# We have two categorical (boolean) features Net Income Flag and Liability-Assets Flag. Both features are heavily skewed.

# %% [markdown]
# ## Identify Constant features

# %%
# Identify constant features (features with only one unique value)
constant_features = []
for col in df.columns:
    if df[col].nunique() == 1:
        constant_features.append(col)

print(f"Constant features found: {len(constant_features)}\n")
if constant_features:
    for feature in constant_features:
        unique_val = df[feature].unique()[0]
        print(f"  - {feature}: {unique_val}")
else:
    print("No constant features found.")
# Out:
# Constant features found: 3
#
#   - Liability-Assets Flag: 0
#   - Net Income Flag: 1
#   - Cluster: 2

# %% [markdown]
# ## Drop constant features and index

# %%
df = df.drop(columns=["Index", "Liability-Assets Flag", "Net Income Flag", "Cluster"])
df.shape
# Out:
# (904, 94)

# %%
df.head()
# Out:
#    Bankrupt?  ROA(C) before interest and depreciation before interest  \
# 0          0                                           0.483401
# 1          0                                           0.465071
# 2          0                                           0.442500
# 3          0                                           0.445230
# 4          0                                           0.491201
#
#    ROA(A) before interest and % after tax  \
# 0                                0.556694
# 1                                0.533689
# 2                                0.507196
# 3                                0.500273
# 4                                0.556095
#
#    ROA(B) before interest and depreciation after tax  Operating Gross Margin  \
# 0                                           0.536164                0.602445
# 1                                           0.516944                0.594740
# 2                                           0.494941                0.598906
# 3                                           0.500990                0.601277
# 4                                           0.544944                0.599728
#
#    Realized Sales Gross Margin  Operating Profit Rate  \
# 0                     0.602445               0.999035
# 1                     0.594740               0.998962
# 2                     0.598812               0.998927
# 3                     0.601277               0.998940
# 4                     0.599728               0.999011
#
#    Pre-tax net Interest Rate  After-tax net Interest Rate  \
# 0                   0.797458                     0.809380
# 1                   0.797393                     0.809313
# 2                   0.797298                     0.809236
# 3                   0.797289                     0.809233
# 4                   0.797414                     0.809335
#
#    Non-industry income and expenditure/revenue  ...  \
# 0                                     0.303506  ...
# 1                                     0.303544  ...
# 2                                     0.303453  ...
# 3                                     0.303410  ...
# 4                                     0.303479  ...
#
#    Current Liability to Current Assets  Net Income to Total Assets  \
# 0                             0.034617                    0.806477
# 1                             0.034854                    0.796315
# 2                             0.025404                    0.780905
# 3                             0.040409                    0.774922
# 4                             0.058151                    0.802420
#
#    Total assets to GNP price  No-credit Interval  Gross Profit to Sales  \
# 0                   0.002177            0.621610               0.602444
# 1                   0.054013            0.613323               0.594736
# 2                   0.009173            0.624087               0.598903
# 3                   0.002127            0.623572               0.601277
# 4                   0.003267            0.622668               0.599728
#
#    Net Income to Stockholder's Equity  Liability to Equity  \
# 0                            0.841891             0.293391
# 1                            0.840085             0.285529
# 2                            0.838903             0.278959
# 3                            0.837951             0.282391
# 4                            0.840690             0.282521
#
#    Degree of Financial Leverage (DFL)  \
# 0                            0.027063
# 1                            0.029521
# 2                            0.026643
# 3                            0.026686
# 4                            0.028464
#
#    Interest Coverage Ratio (Interest expense to EBIT)  Equity to Liability
# 0                                           0.566190              0.015406
# 1                                           0.568791              0.019155
# 2                                           0.564335              0.032862
# 3                                           0.564603              0.022788
# 4                                           0.568246              0.022580
#
# [5 rows x 94 columns]

# %% [markdown]
# ## Missing Values Analysis

# %%
# Check for missing values
print("Missing values summary:")
print("="*50)
missing_values = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

# Create summary dataframe
missing_summary = pd.DataFrame({
    'Column': df.columns,
    'Missing Count': missing_values.values,
    'Missing %': missing_percent.values
})

# Filter to show only columns with missing values
missing_summary = missing_summary[missing_summary['Missing Count'] > 0].sort_values('Missing Count', ascending=False)

if len(missing_summary) == 0:
    print("\n✓ No missing values found in the dataset!")
else:
    print(f"\nFound {len(missing_summary)} columns with missing values:\n")
    print(missing_summary.to_string(index=False))

print(f"\n{'='*50}")
print(f"Total samples: {len(df)}")
print(f"Total features: {len(df.columns)}")
# Out:
# Missing values summary:
# ==================================================
#
# ✓ No missing values found in the dataset!
#
# ==================================================
# Total samples: 904
# Total features: 94

# %% [markdown]
# ## Feature Normalization Analysis

# %%
# Identify features NOT normalized between 0 and 1
non_normalized = []
normalization_summary = []

for col in df.columns:
    if col == "Bankrupt?":  # Skip target variable
        continue
    
    min_val = df[col].min()
    max_val = df[col].max()
    is_normalized = (min_val >= 0) and (max_val <= 1)
    
    normalization_summary.append({
        'Feature': col,
        'Min': min_val,
        'Max': max_val,
        'Normalized': 'Yes' if is_normalized else 'No'
    })
    
    if not is_normalized:
        non_normalized.append(col)

# Create summary dataframe
norm_df = pd.DataFrame(normalization_summary)
non_norm_df = norm_df[norm_df['Normalized'] == 'No'].sort_values('Min')

print(f"Features NOT normalized between 0 and 1: {len(non_normalized)}\n")
print(non_norm_df.to_string(index=False))
print(f"\n{'='*80}")
print(f"Features normalized between 0 and 1: {len(norm_df) - len(non_normalized)}")
print(f"Total features: {len(norm_df)}")
# Out:
# Features NOT normalized between 0 and 1: 15
#
#                               Feature      Min          Max Normalized
# Research and development expense rate 0.000000 9.920000e+09         No
#   Interest-bearing debt interest rate 0.000000 4.700000e+08         No
# Long-term Liability to Current Assets 0.000000 9.030000e+09         No
#           Inventory/Current Liability 0.000000 5.280000e+09         No
#           Current Asset Turnover Rate 0.000000 9.980000e+09         No
#                Operating Expense Rate 0.000100 9.970000e+09         No
#             Quick Asset Turnover Rate 0.000100 1.000000e+10         No
#       Inventory Turnover Rate (times) 0.000100 9.990000e+09         No
#               Total Asset Growth Rate 0.000100 9.880000e+09         No
#       Fixed Assets Turnover Frequency 0.000101 9.910000e+09         No
#                    Cash Turnover Rate 0.000101 9.990000e+09         No
#             Total assets to GNP price 0.000102 9.820000e+09         No
#                Cash/Current Liability 0.000108 9.170000e+09         No
#        Quick Assets/Current Liability 0.000163 8.820000e+09         No
#            Allocation rate per person 0.000164 2.320000e+07         No
#
# ================================================================================
# Features normalized between 0 and 1: 78
# Total features: 93

# %%
attributes_df = df.drop(columns=["Bankrupt?"])
target_df = df["Bankrupt?"]

print(attributes_df.shape)
print(target_df.shape)
# Out:
# (904, 93)
# (904,)

# %%
from sklearn.preprocessing import MinMaxScaler

# Rebuild non_normalized list for attributes_df (with cleaned column names)
non_normalized_in_attrs = []
for col in attributes_df.columns:
    min_val = attributes_df[col].min()
    max_val = attributes_df[col].max()
    is_normalized = (min_val >= 0) and (max_val <= 1)
    
    if not is_normalized:
        non_normalized_in_attrs.append(col)

print(f"Features to scale: {len(non_normalized_in_attrs)}")

# IMPORTANT: Save a copy of raw attributes_df BEFORE scaling (needed for fitting final scaler later)
attributes_df_raw = attributes_df.copy()

# Initialize MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Apply scaling to non-normalized features in attributes_df
if len(non_normalized_in_attrs) > 0:
    attributes_df[non_normalized_in_attrs] = scaler.fit_transform(attributes_df[non_normalized_in_attrs])
    print(f"Scaled {len(non_normalized_in_attrs)} features using MinMaxScaler")
else:
    print("No features to scale")

print(f"\nAttributes dataframe shape: {attributes_df.shape}")
# Out:
# Features to scale: 15
# Scaled 15 features using MinMaxScaler
#
# Attributes dataframe shape: (904, 93)

# %%
# Verify all features in attributes_df are now normalized between 0 and 1
non_normalized = []
normalization_summary = []

tolerance = 1e-10

for col in attributes_df.columns:    
    min_val = attributes_df[col].min()
    max_val = attributes_df[col].max()
    is_normalized = (min_val >= -tolerance) and (max_val <= 1 + tolerance)
    
    normalization_summary.append({
        'Feature': col,
        'Min': min_val,
        'Max': max_val,
        'Normalized': 'Yes' if is_normalized else 'No'
    })
    
    if not is_normalized:
        non_normalized.append(col)

# Create summary dataframe
norm_df = pd.DataFrame(normalization_summary)
non_norm_df = norm_df[norm_df['Normalized'] == 'No'].sort_values('Min')

print(f"Features NOT normalized between 0 and 1: {len(non_normalized)}\n")
if len(non_normalized) > 0:
    print(non_norm_df.to_string(index=False))
else:
    print("✓ All features are now normalized!")
print(f"\n{'='*80}")
print(f"Features normalized between 0 and 1: {len(norm_df) - len(non_normalized)}")
print(f"Total features: {len(norm_df)}")
# Out:
# Features NOT normalized between 0 and 1: 0
#
# ✓ All features are now normalized!
#
# ================================================================================
# Features normalized between 0 and 1: 93
# Total features: 93

# %% [markdown]
# ## Feature Variance Analysis

# %%
from sklearn.feature_selection import VarianceThreshold

# Keep features with variance above threshold
# Low variance = feature is nearly constant across all samples (not informative)
# High variance = feature changes significantly (more informative)
#selector = VarianceThreshold(threshold=0.000000)   # yields all 93 features, no filter
#selector = VarianceThreshold(threshold=0.0001)   # yields 72 features
selector = VarianceThreshold(threshold=0.001)   # yields 40 features
#selector = VarianceThreshold(threshold=0.01)    # yields 13 features


selector.fit(attributes_df)
attributes_df_var = attributes_df.loc[:, selector.get_support()]

# Show dropped features
support_mask = selector.get_support()
dropped_features = attributes_df.columns[~support_mask].tolist()

print(f"Features remaining: {attributes_df_var.shape[1]}")
print(f"Features dropped: {len(dropped_features)}\n")
print("Dropped features (low variance):")
print("="*60)
for i, feature in enumerate(dropped_features, 1):
    variance = attributes_df[feature].var()
    print(f"{i}. {feature} (variance: {variance:.6f})")
# Out:
# Features remaining: 40
# Features dropped: 53
#
# Dropped features (low variance):
# ============================================================
# 1. Operating Gross Margin (variance: 0.000115)
# 2. Realized Sales Gross Margin (variance: 0.000115)
# 3. Operating Profit Rate (variance: 0.000001)
# 4. Pre-tax net Interest Rate (variance: 0.000001)
# 5. After-tax net Interest Rate (variance: 0.000001)
# 6. Non-industry income and expenditure/revenue (variance: 0.000000)
# 7. Continuous interest rate (after tax) (variance: 0.000001)
# 8. Cash flow rate (variance: 0.000027)
# 9. Net Value Per Share (B) (variance: 0.000261)
# 10. Net Value Per Share (A) (variance: 0.000265)
# 11. Net Value Per Share (C) (variance: 0.000266)
# 12. Persistent EPS in the Last Four Seasons (variance: 0.000460)
# 13. Cash Flow Per Share (variance: 0.000139)
# 14. Revenue Per Share (Yuan ¥) (variance: 0.000667)
# 15. Operating Profit Per Share (Yuan ¥) (variance: 0.000215)
# 16. Per Share Net profit before tax (Yuan ¥) (variance: 0.000409)
# 17. Realized Sales Gross Profit Growth Rate (variance: 0.000006)
# 18. Operating Profit Growth Rate (variance: 0.000006)
# 19. After-tax Net Profit Growth Rate (variance: 0.000392)
# 20. Regular Net Profit Growth Rate (variance: 0.000396)
# 21. Continuous Net Profit Growth Rate (variance: 0.000022)
# 22. Net Value Growth Rate (variance: 0.000000)
# 23. Total Asset Return Growth Rate Ratio (variance: 0.000001)
# 24. Cash Reinvestment % (variance: 0.000929)
# 25. Current Ratio (variance: 0.000010)
# 26. Quick Ratio (variance: 0.000007)
# 27. Interest Expense Ratio (variance: 0.000126)
# 28. Long-term fund suitability ratio (A) (variance: 0.000123)
# 29. Operating profit/Paid-in capital (variance: 0.000207)
# 30. Net profit before tax/Paid-in capital (variance: 0.000340)
# 31. Inventory and accounts receivable/Net value (variance: 0.000226)
# 32. Accounts Receivable Turnover (variance: 0.000005)
# 33. Average Collection Days (variance: 0.000018)
# 34. Net Worth Turnover Rate (times) (variance: 0.000844)
# 35. Revenue per person (variance: 0.001001)
# 36. Operating profit per person (variance: 0.000299)
# 37. Operating Funds to Liability (variance: 0.000168)
# 38. Inventory/Working Capital (variance: 0.000139)
# 39. Working Capital/Equity (variance: 0.000760)
# 40. Current Liabilities/Equity (variance: 0.000924)
# 41. Retained Earnings to Total Assets (variance: 0.000914)
# 42. Total income/Total expense (variance: 0.000000)
# 43. Working capitcal Turnover Rate (variance: 0.000000)
# 44. Cash Flow to Sales (variance: 0.000000)
# 45. Current Liability to Equity (variance: 0.000924)
# 46. Cash Flow to Liability (variance: 0.000058)
# 47. Cash Flow to Equity (variance: 0.000719)
# 48. Current Liability to Current Assets (variance: 0.000320)
# 49. No-credit Interval (variance: 0.000011)
# 50. Gross Profit to Sales (variance: 0.000115)
# 51. Degree of Financial Leverage (DFL) (variance: 0.000701)
# 52. Interest Coverage Ratio (Interest expense to EBIT) (variance: 0.000187)
# 53. Equity to Liability (variance: 0.000046)

# %%
print(attributes_df_var.shape)
attributes_df_var.describe()
# Out:
# (904, 40)
#        ROA(C) before interest and depreciation before interest  \
# count                                         904.000000
# mean                                            0.454117
# std                                             0.058792
# min                                             0.000000
# 25%                                             0.435187
# 50%                                             0.469410
# 75%                                             0.489945
# max                                             0.574367
#
#        ROA(A) before interest and % after tax  \
# count                              904.000000
# mean                                 0.506552
# std                                  0.070122
# min                                  0.006923
# 25%                                  0.484409
# 50%                                  0.527775
# 75%                                  0.548585
# max                                  0.635794
#
#        ROA(B) before interest and depreciation after tax  \
# count                                         904.000000
# mean                                            0.502734
# std                                             0.064373
# min                                             0.000000
# 25%                                             0.481784
# 50%                                             0.520370
# 75%                                             0.541290
# max                                             0.630708
#
#        Operating Expense Rate  Research and development expense rate  \
# count            9.040000e+02                             904.000000
# mean             1.564669e-01                               0.195736
# std              3.057808e-01                               0.274638
# min              0.000000e+00                               0.000000
# 25%              4.581344e-15                               0.000000
# 50%              1.228270e-14                               0.034274
# 75%              5.007523e-02                               0.332157
# max              1.000000e+00                               1.000000
#
#        Interest-bearing debt interest rate  Tax rate (A)  \
# count                         9.040000e+02    904.000000
# mean                          2.607795e-03      0.063367
# std                           4.773329e-02      0.139200
# min                           0.000000e+00      0.000000
# 25%                           5.915489e-13      0.000000
# 50%                           8.330617e-13      0.000000
# 75%                           1.279915e-12      0.053674
# max                           1.000000e+00      0.988865
#
#        Total Asset Growth Rate  Total debt/Total net worth  Debt ratio %  ...  \
# count               904.000000                  904.000000    904.000000  ...
# mean                  0.532986                    0.016291      0.164066  ...
# std                   0.267241                    0.044854      0.037373  ...
# min                   0.000000                    0.002651      0.066330  ...
# 25%                   0.452682                    0.008061      0.138699  ...
# 50%                   0.608806                    0.011007      0.161835  ...
# 75%                   0.709514                    0.015414      0.186141  ...
# max                   1.000000                    1.000000      0.295190  ...
#
#        Cash Turnover Rate  Fixed Assets to Assets  \
# count          904.000000              904.000000
# mean             0.311706                0.220771
# std              0.283405                0.147703
# min              0.000000                0.000424
# 25%              0.057633                0.104287
# 50%              0.231732                0.191849
# 75%              0.528028                0.310583
# max              1.000000                0.695298
#
#        Current Liability to Liability  Equity to Long-term Liability  \
# count                      904.000000                     904.000000
# mean                         0.807990                       0.119129
# std                          0.159483                       0.037975
# min                          0.209586                       0.110933
# 25%                          0.708009                       0.111038
# 50%                          0.842779                       0.114488
# 75%                          0.938247                       0.120023
# max                          1.000000                       0.922128
#
#        Cash Flow to Total Assets  CFO to Assets  Net Income to Total Assets  \
# count                 904.000000     904.000000                  904.000000
# mean                    0.639265       0.558279                    0.775409
# std                     0.040010       0.061743                    0.051284
# min                     0.167678       0.074249                    0.224792
# 25%                     0.631214       0.534319                    0.765626
# 50%                     0.642103       0.567432                    0.791255
# 75%                     0.652248       0.591658                    0.802528
# max                     0.935312       0.762217                    0.849314
#
#        Total assets to GNP price  Net Income to Stockholder's Equity  \
# count               9.040000e+02                          904.000000
# mean                4.935070e-03                            0.834917
# std                 6.033538e-02                            0.037129
# min                 0.000000e+00                            0.000000
# 25%                 7.668103e-14                            0.836821
# 50%                 1.653100e-13                            0.839606
# 75%                 4.004983e-13                            0.840741
# max                 1.000000e+00                            0.846063
#
#        Liability to Equity
# count           904.000000
# mean              0.286594
# std               0.032529
# min               0.276702
# 25%               0.280625
# 50%               0.282761
# 75%               0.285957
# max               1.000000
#
# [8 rows x 40 columns]

# %%
attributes_df_var.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 40 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   ROA(C) before interest and depreciation before interest  904 non-null    float64
#  1   ROA(A) before interest and % after tax                   904 non-null    float64
#  2   ROA(B) before interest and depreciation after tax        904 non-null    float64
#  3   Operating Expense Rate                                   904 non-null    float64
#  4   Research and development expense rate                    904 non-null    float64
#  5   Interest-bearing debt interest rate                      904 non-null    float64
#  6   Tax rate (A)                                             904 non-null    float64
#  7   Total Asset Growth Rate                                  904 non-null    float64
#  8   Total debt/Total net worth                               904 non-null    float64
#  9   Debt ratio %                                             904 non-null    float64
#  10  Net worth/Assets                                         904 non-null    float64
#  11  Borrowing dependency                                     904 non-null    float64
#  12  Contingent liabilities/Net worth                         904 non-null    float64
#  13  Total Asset Turnover                                     904 non-null    float64
#  14  Inventory Turnover Rate (times)                          904 non-null    float64
#  15  Fixed Assets Turnover Frequency                          904 non-null    float64
#  16  Allocation rate per person                               904 non-null    float64
#  17  Working Capital to Total Assets                          904 non-null    float64
#  18  Quick Assets/Total Assets                                904 non-null    float64
#  19  Current Assets/Total Assets                              904 non-null    float64
#  20  Cash/Total Assets                                        904 non-null    float64
#  21  Quick Assets/Current Liability                           904 non-null    float64
#  22  Cash/Current Liability                                   904 non-null    float64
#  23  Current Liability to Assets                              904 non-null    float64
#  24  Inventory/Current Liability                              904 non-null    float64
#  25  Current Liabilities/Liability                            904 non-null    float64
#  26  Long-term Liability to Current Assets                    904 non-null    float64
#  27  Total expense/Assets                                     904 non-null    float64
#  28  Current Asset Turnover Rate                              904 non-null    float64
#  29  Quick Asset Turnover Rate                                904 non-null    float64
#  30  Cash Turnover Rate                                       904 non-null    float64
#  31  Fixed Assets to Assets                                   904 non-null    float64
#  32  Current Liability to Liability                           904 non-null    float64
#  33  Equity to Long-term Liability                            904 non-null    float64
#  34  Cash Flow to Total Assets                                904 non-null    float64
#  35  CFO to Assets                                            904 non-null    float64
#  36  Net Income to Total Assets                               904 non-null    float64
#  37  Total assets to GNP price                                904 non-null    float64
#  38  Net Income to Stockholder's Equity                       904 non-null    float64
#  39  Liability to Equity                                      904 non-null    float64
# dtypes: float64(40)
# memory usage: 282.6 KB

# %% [markdown]
# ## Stacking model

# %%
from sklearn.ensemble import StackingClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# Reset indices to ensure alignment between X and y
X = attributes_df_var.reset_index(drop=True)
y = target_df.reset_index(drop=True)

print(f"Class distribution - Negative: {(y == 0).sum()}, Positive: {(y == 1).sum()}")
print(f"Imbalance ratio: {(y == 0).sum() / (y == 1).sum():.2f}:1")

# Base learners optimized for imbalanced data (sklearn only)
base_learners = [
    ('gb', GradientBoostingClassifier(
        n_estimators=100,
        max_depth=5,
        learning_rate=0.1,
        subsample=0.8,
        random_state=42
    )),
    ('svc', SVC(
        kernel='rbf',
        C=10,
        class_weight='balanced',
        probability=True,
        random_state=42
    )),
    ('rf', RandomForestClassifier(
        n_estimators=100,
        max_depth=10,
        class_weight='balanced_subsample',
        random_state=42,
        n_jobs=-1
    )),
    ('lr', LogisticRegression(
        C=1.0,
        class_weight='balanced',
        max_iter=1000,
        random_state=42
    ))
]

# Meta-learner: Logistic Regression with balanced class weights
meta_learner = LogisticRegression(
    C=1.0,
    class_weight='balanced',
    max_iter=1000,
    random_state=42
)

# Create stacking classifier
clf = StackingClassifier(
    estimators=base_learners,
    final_estimator=meta_learner,
    cv=5
)

# Train and evaluate
result = clf.fit(X, y).score(X, y)
print(f"\nStacking Model (without CV) - Training Accuracy: {round(result, 3)}")

# Use cross validation
clf_cv = StackingClassifier(
    estimators=base_learners,
    final_estimator=meta_learner,
    cv=10
)
result_cv = clf_cv.fit(X, y).score(X, y)
print(f"Stacking Model (with CV) - Training Accuracy: {round(result_cv, 3)}")
# Out:
# Class distribution - Negative: 803, Positive: 101
# Imbalance ratio: 7.95:1
#
# Stacking Model (without CV) - Training Accuracy: 0.897
# Stacking Model (with CV) - Training Accuracy: 0.909

# %%
from sklearn.metrics import recall_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Model 1: Without cross-validation (using updated base_learners and meta_learner)
clf_no_cv = StackingClassifier(
    estimators=base_learners,
    final_estimator=meta_learner,
    cv=5
)
clf_no_cv.fit(X, y)
y_pred_no_cv = clf_no_cv.predict(X)

# Model 2: With cross-validation
clf_cv = StackingClassifier(
    estimators=base_learners,
    final_estimator=meta_learner,
    cv=10
)
clf_cv.fit(X, y)
y_pred_cv = clf_cv.predict(X)

print("="*80)
print("MINORITY CLASS (Bankrupt? = 1) RECALL EVALUATION")
print("="*80)

# Recall without cross-validation
recall_no_cv = recall_score(y, y_pred_no_cv, pos_label=1)
tn, fp, fn, tp = confusion_matrix(y, y_pred_no_cv).ravel()
recall_formula = tp / (fn + tp)

print(f"\nModel WITHOUT Cross-Validation:")
print(f"  Recall (sklearn): {recall_no_cv:.4f}")
print(f"  Recall Formula TP/(FN+TP): {recall_formula:.4f}")
print(f"  Confusion Matrix: TP={tp}, FN={fn}, FP={fp}, TN={tn}")

# Recall with cross-validation
recall_cv = recall_score(y, y_pred_cv, pos_label=1)
tn, fp, fn, tp = confusion_matrix(y, y_pred_cv).ravel()
recall_formula_cv = tp / (fn + tp)

print(f"\nModel WITH Cross-Validation:")
print(f"  Recall (sklearn): {recall_cv:.4f}")
print(f"  Recall Formula TP/(FN+TP): {recall_formula_cv:.4f}")
print(f"  Confusion Matrix: TP={tp}, FN={fn}, FP={fp}, TN={tn}")

# Create confusion matrices
cm_no_cv = confusion_matrix(y, y_pred_no_cv)
cm_cv = confusion_matrix(y, y_pred_cv)

# Create subplots for both confusion matrices
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Confusion Matrix without Cross-Validation
ax = axes[0]
sns.heatmap(cm_no_cv, annot=True, fmt='g', ax=ax, cmap='Blues')
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix - Without Cross-Validation')
ax.xaxis.set_ticklabels(['Non-Bankrupt', 'Bankrupt'])
ax.yaxis.set_ticklabels(['Non-Bankrupt', 'Bankrupt'])

# Plot 2: Confusion Matrix with Cross-Validation
ax = axes[1]
sns.heatmap(cm_cv, annot=True, fmt='g', ax=ax, cmap='Blues')
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix - With Cross-Validation')
ax.xaxis.set_ticklabels(['Non-Bankrupt', 'Bankrupt'])
ax.yaxis.set_ticklabels(['Non-Bankrupt', 'Bankrupt'])

plt.tight_layout()
plt.show()

print(f"\n{'='*80}")
print("Detailed Classification Report (CV Model):")
print(f"{'='*80}")
print(classification_report(y, y_pred_cv, target_names=['Non-Bankrupt', 'Bankrupt']))
# Out:
# ================================================================================
# MINORITY CLASS (Bankrupt? = 1) RECALL EVALUATION
# ================================================================================
#
# Model WITHOUT Cross-Validation:
#   Recall (sklearn): 1.0000
#   Recall Formula TP/(FN+TP): 1.0000
#   Confusion Matrix: TP=101, FN=0, FP=93, TN=710
#
# Model WITH Cross-Validation:
#   Recall (sklearn): 1.0000
#   Recall Formula TP/(FN+TP): 1.0000
#   Confusion Matrix: TP=101, FN=0, FP=82, TN=721
# ================================================================================
# Detailed Classification Report (CV Model):
# ================================================================================
#               precision    recall  f1-score   support
#
# Non-Bankrupt       1.00      0.90      0.95       803
#     Bankrupt       0.55      1.00      0.71       101
#
#     accuracy                           0.91       904
#    macro avg       0.78      0.95      0.83       904
# weighted avg       0.95      0.91      0.92       904

# %% [markdown]
# ## SVC, kNN, and DT. Meta: Logistic
#
# ### 95 features:
# 0.1980
#
# ### 72 features
# 0.2079
#
# ### 40 Features (variance filter)
#
# 0.1980
#
# ### 13 Features (variance filter)
# 0
